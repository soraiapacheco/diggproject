# %%
# Chapter 18 - Power Law - Long Tail - This graphic is better for explain 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnodestatic.csv") 

plt.scatter(data.indegree, data.Id, color = 'b') # power law analysis => in degree => x and no nodes (id of the users) => y

plt.show()

# %%
# Chapter 18 - Power Law - Long Tail

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnodestatic.csv")

 
plt.bar(data.indegree, data.Id, color = 'b') # power law analysis => in degree => x and no nodes (id of the users) => y


plt.show()

# %%
# Chapter 18 - Power Law - others comparisons (degree, indegree and outdegree changing the orientation)

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnodestatic.csv")
dtnode = data
dtnode
dtnode.plot(y=['Degree',"indegree","outdegree"], x='Id', subplots=True,  layout=(2,2)) # power law analysis => in degree => x and no nodes => y
#plt.plot(data.Target, data.Source)

#plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6723ae890>,
# ...
#       dtype=object)

# %%
# chapter 21 - epidemics(sir) model (users: Julie (72)) - The view of the Gephi is better

import networkx as nx
import pandas as pd 
import matplotlib.pyplot as plt



data = pd.read_csv("diggtempo0424.csv")

dttarget = data[data.Source == 72]


# Make a list of the users, we'll use it later
users = list(dttarget.Source.unique())


# Make a list of the people, we'll use it later
people = list(dttarget.Target.unique())

# 1. Create the graph
g = nx.from_pandas_edgelist(dttarget, source='Source', target='Target') 


# 2. Create a layout for our nodes 
layout = nx.spring_layout(g,iterations=50)



# 3. Draw the parts we want
# Edges thin and grey
# People small and grey
# Clubs sized according to their number of connections
# Clubs blue
# Labels for clubs ONLY
# People who are highly connected are a highlighted color

# Go through every club name, ask the graph how many
# connections it has. Multiply that by 80 to get the circle size
user_size = [g.degree(user) * 70 for user in users]
nx.draw_networkx_nodes(g, 
                       layout, 
                       nodelist=users, 
                       node_size=user_size, # a LIST of sizes, based on g.degree
                       node_color='lightblue')

# Draw EVERYONE
nx.draw_networkx_nodes(g, layout, nodelist=people, node_color='#cccccc', node_size=100)


#g = nx.from_pandas_dataframe(dttarget, source='Source', target='Target') 

#nx.draw(g)

#plt.show()

#g.add_edges_from(people)


# Draw POPULAR PEOPLE
popular_people = [person for person in people if g.degree(person) > 1]
nx.draw_networkx_nodes(g, layout, nodelist=popular_people, node_color='lightblue', node_size=100)

nx.draw_networkx_edges(g, layout, width=1, edge_color="#cccccc")

node_labels = dict(zip(users, users))
nx.draw_networkx_labels(g, layout, labels=node_labels, arrows=True)


# 4. Turn off the axis because I know you don't want it
plt.axis('off')

plt.title("User Digg")

# 5. Tell matplotlib to show it
plt.show()

# %%
# chapter 21 - epidemics(sir) model (users: Julie, John and Philip)


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnode727173.csv")
dtnode = data[data.Source==72]
data
#dtnode
#dtnode.plot(y=['Degree',"indegree","outdegree"], x='Id') # power law analysis => in degree => x and no nodes => y
#plt.plot(data.Target, data.Source)

dtnode.plot(x='timestamp', y='Target', kind='scatter')

plt.show()
#plt.show()

# %%
# chapter 21 - epidemics(sir and sis) model (users: Julie (72), John (71) and Philip (73))

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnode727173.csv")
dtnode = data[(data.Source.isin([71,72,73]))] # only nodes 71,72 and 73 like source
dtnode


dtnode.plot(x='timestamp', y='Target', kind='scatter')

# %%
# chapter 21 - epidemics(sir) model (user: John (71))

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnode727173.csv")
dtnode = data[data.Source==71] # user John
data

dtnode.plot(x='timestamp', y='Target', kind='scatter')

plt.show()
#plt.show()

# %%
# chapter 21 - epidemics(sir) model (user: Philip (73))


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnode727173.csv")
dtnode = data[data.Source==72]

data.plot(x='timestamp', y='Target', kind='scatter')

plt.show()

# %%
# chapter 21 - epidemics(sir) model (users: Julie (72), John (71) and Philip (73)) - Source and Target Y-axis


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("diggnode727173.csv")
data

data.plot(x='timestamp', y=['Source','Target'], kind='line')
plt.show()
